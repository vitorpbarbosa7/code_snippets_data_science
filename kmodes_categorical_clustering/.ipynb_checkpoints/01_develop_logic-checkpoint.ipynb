# %% [markdown]
# # Boilerplate

# %%
import pandas as pd 
import pandasql as ps
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
import scipy.stats as stats
import statsmodels.stats.api as sms

from IPython.display import display
from IPython.display import Markdown as md
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

def f():
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)
    
def nf():
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', 4)

import warnings
warnings.filterwarnings('ignore')

def dp(df, r = 5, c = None):
    from IPython.display import display
    with pd.option_context('display.max_rows', 4, 'display.max_columns', None):
        display(df)

def fg(w = 6, h = 4, dpi = 120):
    plt.rcParams['figure.figsize'] = (w,h)
    plt.rcParams['figure.dpi'] = dpi
fg()

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Create sample

# %%
import random 
import string

# %%
# letters = string.ascii_uppercase
letters = string.ascii_uppercase[:5]

df = pd.DataFrame()
_len = 200
for i in range(5):
    df[f'Q{i}'] = [''.join(random.choice(letters) for _ in range(1)) for _ in range(_len)]

# %%
df
# Out:
#     Q0 Q1 Q2 Q3 Q4
# 0    A  A  A  B  A
# 1    B  C  B  D  C
# 2    E  A  B  C  D
# 3    C  B  C  E  A
# 4    B  B  B  C  C
# ..  .. .. .. .. ..
# 195  A  E  B  A  E
# 196  B  B  D  E  C
# 197  D  D  E  D  A
# 198  C  C  B  D  A
# 199  C  D  A  B  C
#
# [200 rows x 5 columns]

# %% [markdown]
# # random sample selection

# %%
n_clu = 3
_cho = random.sample(df.index.to_list(),n_clu)

dfcho = df[df.index.isin(_cho)].reset_index(drop = True)

# %%
dforig = df.copy()

# %% [markdown]
# # Compute distances

# %%
# computacao ineficient O(n²) ou mais
for idx in df.index:
    for clu in dfcho.index:
        df.loc[idx,f'C{clu}'] = sum(dforig.iloc[idx,:] == dfcho.iloc[clu,:])

# %%
df
# Out:
#     Q0 Q1 Q2 Q3 Q4   C0   C1   C2 closest
# 0    A  A  A  B  A  3.0  3.0  3.0      C2
# 1    B  C  B  D  C  1.0  2.0  3.0      C1
# 2    E  A  B  C  D  3.0  4.0  3.0      C0
# 3    C  B  C  E  A  2.0  0.0  1.0      C0
# 4    B  B  B  C  C  4.0  4.0  1.0      C2
# ..  .. .. .. .. ..  ...  ...  ...     ...
# 195  A  E  B  A  E  2.0  1.0  1.0     NaN
# 196  B  B  D  E  C  2.0  3.0  0.0     NaN
# 197  D  D  E  D  A  2.0  1.0  4.0     NaN
# 198  C  C  B  D  A  3.0  2.0  2.0     NaN
# 199  C  D  A  B  C  3.0  2.0  1.0     NaN
#
# [200 rows x 9 columns]

# %% [markdown]
# # Minimum distances to clusters

# %%
dfclosest = df.select_dtypes(include = [float]).idxmin(axis = 1)

# %%
df['closest'] = dfclosest

# %%
df
# Out:
#     Q0 Q1 Q2 Q3 Q4   C0   C1   C2 closest
# 0    A  A  A  B  A  3.0  3.0  3.0      C0
# 1    B  C  B  D  C  1.0  2.0  3.0      C0
# 2    E  A  B  C  D  3.0  4.0  3.0      C0
# 3    C  B  C  E  A  2.0  0.0  1.0      C1
# 4    B  B  B  C  C  4.0  4.0  1.0      C2
# ..  .. .. .. .. ..  ...  ...  ...     ...
# 195  A  E  B  A  E  2.0  1.0  1.0      C1
# 196  B  B  D  E  C  2.0  3.0  0.0      C2
# 197  D  D  E  D  A  2.0  1.0  4.0      C1
# 198  C  C  B  D  A  3.0  2.0  2.0      C1
# 199  C  D  A  B  C  3.0  2.0  1.0      C2
#
# [200 rows x 9 columns]

# %%
clusters = df.select_dtypes(include = [float]).columns

# %%
for clu in clusters:
    df[df.closest == clu]
# 161  A  D  C  D  A  3.0  1.0  2.0      C1
# 166  C  D  E  B  D  3.0  2.0  2.0      C1
# 167  A  B  E  A  D  4.0  2.0  3.0      C1
# 169  A  C  C  D  E  3.0  1.0  1.0      C1
# 171  A  B  E  D  A  5.0  2.0  3.0      C1
# 173  A  E  A  D  A  2.0  0.0  2.0      C1
# 174  C  B  C  D  A  2.0  0.0  2.0      C1
# 176  D  C  A  C  C  2.0  1.0  1.0      C1
# 180  D  B  A  D  C  3.0  1.0  1.0      C1
# 184  D  B  C  D  A  2.0  0.0  2.0      C1
# 187  C  B  D  A  B  1.0  0.0  0.0      C1
# 193  E  D  E  C  D  2.0  1.0  3.0      C1
# 194  C  D  C  E  A  2.0  1.0  1.0      C1
# 195  A  E  B  A  E  2.0  1.0  1.0      C1
# 197  D  D  E  D  A  2.0  1.0  4.0      C1
# 198  C  C  B  D  A  3.0  2.0  2.0      C1
#     Q0 Q1 Q2 Q3 Q4   C0   C1   C2 closest
# 4    B  B  B  C  C  4.0  4.0  1.0      C2
# 9    E  B  B  E  E  5.0  3.0  1.0      C2
# 13   D  B  B  E  D  5.0  3.0  0.0      C2
# 16   C  E  C  C  E  2.0  1.0  0.0      C2
# 18   C  E  C  A  D  2.0  2.0  1.0      C2
# ..  .. .. .. .. ..  ...  ...  ...     ...
# 179  D  C  D  A  B  1.0  1.0  0.0      C2
# 182  E  D  B  D  D  4.0  3.0  2.0      C2
# 185  B  B  D  E  E  1.0  2.0  0.0      C2
# 196  B  B  D  E  C  2.0  3.0  0.0      C2
# 199  C  D  A  B  C  3.0  2.0  1.0      C2
#
# [64 rows x 9 columns]

# %% [markdown]
# # Return mode

# %%
df
# Out:
#     Q0 Q1 Q2 Q3 Q4   C0   C1   C2 closest
# 0    A  A  A  B  A  3.0  3.0  3.0      C0
# 1    B  C  B  D  C  1.0  2.0  3.0      C0
# 2    E  A  B  C  D  3.0  4.0  3.0      C0
# 3    C  B  C  E  A  2.0  0.0  1.0      C1
# 4    B  B  B  C  C  4.0  4.0  1.0      C2
# ..  .. .. .. .. ..  ...  ...  ...     ...
# 195  A  E  B  A  E  2.0  1.0  1.0      C1
# 196  B  B  D  E  C  2.0  3.0  0.0      C2
# 197  D  D  E  D  A  2.0  1.0  4.0      C1
# 198  C  C  B  D  A  3.0  2.0  2.0      C1
# 199  C  D  A  B  C  3.0  2.0  1.0      C2
#
# [200 rows x 9 columns]

# %%
aux = pd.DataFrame({'a':[1,2,3,2,1,2,3], 'b':[1,4,5,6,4,5,6]})

# %%
aux.mode(axis = 0)
# Out:
#      a  b
# 0  2.0  4
# 1  NaN  5
# 2  NaN  6

# %%
df['Q0'].mode()
# Out:
# 0    A
# dtype: object

# %%
df.mode(axis = 0)
# Out:
#     Q0   Q1 Q2   Q3   Q4   C0   C1   C2 closest
# 0    A    A  B    D    A  2.0  1.0  1.0      C0
# 1  NaN  NaN  C  NaN  NaN  NaN  NaN  NaN     NaN

# %%
dfmode = pd.DataFrame()
for clu in clusters:
    dfmode = dfmode.append(df[df.closest == clu].mode(axis = 0).iloc[0,:])

# %%
dfmode
# Out:
#   Q0 Q1 Q2 Q3 Q4   C0   C1   C2 closest
# 0  B  A  E  D  A  1.0  3.0  3.0      C0
# 0  A  B  E  D  A  2.0  1.0  2.0      C1
# 0  A  B  B  B  D  2.0  3.0  1.0      C2
