# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
import scipy.stats as stats
import statsmodels.stats.api as sms

from IPython.display import display
from IPython.display import Markdown as md
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

def f():
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)
    
def nf():
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', 4)
nf()
import warnings
warnings.filterwarnings('ignore')

def dp(df, r = 5, c = None):
    from IPython.display import display
    with pd.option_context('display.max_rows', 4, 'display.max_columns', None):
        display(df)

def fg(w = 6, h = 4, dpi = 120):
    plt.rcParams['figure.figsize'] = (w,h)
    plt.rcParams['figure.dpi'] = dpi
fg()

# import autotime
# %load_ext autoreload
# %autoreload 2
# %load_ext autotime

# For dark themes 
from jupyterthemes import jtplot
jtplot.style()

# Para quando tiver atualização de submodulos
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv("data/UCI_Credit_Card.csv")

# %%
data.shape
# Out:
# (30000, 25)

# %%
data.columns = data.columns.str.lower()

# %%
data
# Out:
#           id  limit_bal  sex  education  marriage  age  pay_0  pay_2  pay_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
#        pay_4  pay_5  pay_6  bill_amt1  bill_amt2  bill_amt3  bill_amt4  \
# 0         -1     -2     -2     3913.0     3102.0      689.0        0.0
# 1          0      0      2     2682.0     1725.0     2682.0     3272.0
# ...      ...    ...    ...        ...        ...        ...        ...
# 29998      0      0     -1    -1645.0    78379.0    76304.0    52774.0
# 29999      0      0      0    47929.0    48905.0    49764.0    36535.0
#
#        bill_amt5  bill_amt6  pay_amt1  pay_amt2  pay_amt3  pay_amt4  pay_amt5  \
# 0            0.0        0.0       0.0     689.0       0.0       0.0       0.0
# 1         3455.0     3261.0       0.0    1000.0    1000.0    1000.0       0.0
# ...          ...        ...       ...       ...       ...       ...       ...
# 29998    11855.0    48944.0   85900.0    3409.0    1178.0    1926.0   52964.0
# 29999    32428.0    15313.0    2078.0    1800.0    1430.0    1000.0    1000.0
#
#        pay_amt6  default.payment.next.month
# 0           0.0                           1
# 1        2000.0                           1
# ...         ...                         ...
# 29998    1804.0                           1
# 29999    1000.0                           1
#
# [30000 rows x 25 columns]

# %%
data.pay_5.unique()
# Out:
# array([-2,  0, -1,  2,  3,  5,  4,  7,  8,  6])

# %%
f()
data.dtypes
nf()
# Out:
# id                              int64
# limit_bal                     float64
# sex                             int64
# education                       int64
# marriage                        int64
# age                             int64
# pay_0                           int64
# pay_2                           int64
# pay_3                           int64
# pay_4                           int64
# pay_5                           int64
# pay_6                           int64
# bill_amt1                     float64
# bill_amt2                     float64
# bill_amt3                     float64
# bill_amt4                     float64
# bill_amt5                     float64
# bill_amt6                     float64
# pay_amt1                      float64
# pay_amt2                      float64
# pay_amt3                      float64
# pay_amt4                      float64
# pay_amt5                      float64
# pay_amt6                      float64
# default.payment.next.month      int64
# dtype: object

# %%
data = data.rename(columns = {'default.payment.next.month':'target'})

# %%
! ls
# Out:
# _01_dataprep.ipynb			feature_selector
# _02_model_with_average_precision.ipynb	libs
# data					requirements.txt
# feature_select				requirements_.txt
# feature_selection_git

# %%
data.to_parquet('data/data_to_feature_selection.parquet', index = False)

# %%
data.target.value_counts()
# Out:
# 0    23364
# 1     6636
# Name: target, dtype: int64

# %%
X = data.drop('target', axis = 1)

# %%
y = data['target']

# %% [markdown]
# # LGBM

# %%
import lightgbm as lgb

# %%
clf = lgb.LGBMClassifier()

# %%
from libs.mlpkg import ml as ml

# %% [markdown]
# ### Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3)

# %%
m1 = ml(X_train, X_test, y_train, y_test, model = clf, modelname = 'LightGBM')

# %%
m1.scores()
# Out:
#    acuracia  precision  recall    f1   auc  gini
# 0      0.82       0.66    0.37  0.48  0.78  0.56

# %%
m1.matriz()
# Out:
# Matriz de confusão:

# %%
m1.precisionrecall()

# %%
m1.roccurve()

# %% [markdown]
# # Implementar feature selection

# %%
ls
# Out:
# _01_dataprep.ipynb*                      feature_selector/  requirements_.txt*
# _02_model_with_average_precision.ipynb*  libs/
# data/                                    requirements.txt*

# %%
from feature_selector.feature_selector import FeatureSelector

import pandas as pd

# %%
data
# Out:
#           id  limit_bal  sex  education  marriage  age  pay_0  pay_2  pay_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
#        pay_4  pay_5  pay_6  bill_amt1  bill_amt2  bill_amt3  bill_amt4  \
# 0         -1     -2     -2     3913.0     3102.0      689.0        0.0
# 1          0      0      2     2682.0     1725.0     2682.0     3272.0
# ...      ...    ...    ...        ...        ...        ...        ...
# 29998      0      0     -1    -1645.0    78379.0    76304.0    52774.0
# 29999      0      0      0    47929.0    48905.0    49764.0    36535.0
#
#        bill_amt5  bill_amt6  pay_amt1  pay_amt2  pay_amt3  pay_amt4  pay_amt5  \
# 0            0.0        0.0       0.0     689.0       0.0       0.0       0.0
# 1         3455.0     3261.0       0.0    1000.0    1000.0    1000.0       0.0
# ...          ...        ...       ...       ...       ...       ...       ...
# 29998    11855.0    48944.0   85900.0    3409.0    1178.0    1926.0   52964.0
# 29999    32428.0    15313.0    2078.0    1800.0    1430.0    1000.0    1000.0
#
#        pay_amt6  target
# 0           0.0       1
# 1        2000.0       1
# ...         ...     ...
# 29998    1804.0       1
# 29999    1000.0       1
#
# [30000 rows x 25 columns]

# %%
train = data.drop('target', axis = 1)
train_labels = data['target']

# %%
fs = FeatureSelector(data = train, labels = train_labels)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
fs.identify_missing(missing_threshold=0.05)
# Out:
# 0 features with greater than 0.05 missing values.

# %%
fs.identify_single_unique()
# Out:
# 0 features with a single unique value.

# %%
single_unique = fs.ops['single_unique']
single_unique
# Out:
# []

# %%
fs.plot_unique()

# %%
fs.identify_collinear(correlation_threshold=0.8)
# Out:
# 7 features with a correlation magnitude greater than 0.80.

# %%
correlated_features = fs.ops['collinear']
correlated_features[:5]
# Out:
# ['pay_5', 'pay_6', 'bill_amt2', 'bill_amt3', 'bill_amt4']

# %%
fs.plot_collinear()

# %%
fs.plot_collinear(plot_all=True)

# %%
fs.identify_collinear(correlation_threshold=0.98)
fs.plot_collinear()
# Out:
# 0 features with a correlation magnitude greater than 0.98.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-56a502e1bd0f> in <module>
#       1 fs.identify_collinear(correlation_threshold=0.98)
# ----> 2 fs.plot_collinear()
#
# /media/vpb/GD_/USP/DS/_1Git/_02_Scripts_Boilerplates/_03_Credit_Risk_Modelling/feature_selector/feature_selector.py in plot_collinear(self, plot_all)
#     577         # Draw the heatmap with a color bar
#     578         sns.heatmap(corr_matrix_plot, cmap=cmap, center=0,
# --> 579                     linewidths=.25, cbar_kws={"shrink": 0.6})
#     580
#     581         # Set the ylabels
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     510     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     511                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 512                           yticklabels, mask)
#     513
#     514     # Add the pcolormesh kwargs here
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     164         # Determine good default values for the colormapping
#     165         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 166                                     cmap, center, robust)
#     167
#     168         # Sort out the annotations
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     197         calc_data = plot_data.data[~np.isnan(plot_data.data)]
#     198         if vmin is None:
# --> 199             vmin = np.percentile(calc_data, 2) if robust else calc_data.min()
#     200         if vmax is None:
#     201             vmax = np.percentile(calc_data, 98) if robust else calc_data.max()
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
fs.identify_zero_importance(task = 'classification', eval_metric = 'auc', 
                            n_iterations = 10, early_stopping = True)
# Out:
# Training Gradient Boosting Model
#
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [100]	valid_0's auc: 0.792513	valid_0's binary_logloss: 0.418562
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [103]	valid_0's auc: 0.770022	valid_0's binary_logloss: 0.434671
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [81]	valid_0's auc: 0.787182	valid_0's binary_logloss: 0.424679
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [48]	valid_0's auc: 0.783181	valid_0's binary_logloss: 0.428471
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [51]	valid_0's auc: 0.799066	valid_0's binary_logloss: 0.418333
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [63]	valid_0's auc: 0.78361	valid_0's binary_logloss: 0.428328
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [60]	valid_0's auc: 0.79946	valid_0's binary_logloss: 0.41934
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [168]	valid_0's auc: 0.781889	valid_0's binary_logloss: 0.426687
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [75]	valid_0's auc: 0.781473	valid_0's binary_logloss: 0.428323
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [178]	valid_0's auc: 0.793094	valid_0's binary_logloss: 0.419721
#
# 0 features with zero importance after one-hot encoding.

# %%
one_hot_features = fs.one_hot_features
base_features = fs.base_features
print('There are %d original features' % len(base_features))
print('There are %d one-hot features' % len(one_hot_features))
# Out:
# There are 24 original features
# There are 0 one-hot features

# %%
fs.plot_feature_importances(threshold = 0.99, plot_n = 12)
# Out:
# 23 features required for 0.99 of cumulative importance

# %%
f()
fs.feature_importances.head(10)
nf()
# Out:
#      feature  importance  normalized_importance  cumulative_importance
# 0  bill_amt1       251.7               0.090507               0.090507
# 1  limit_bal       234.3               0.084250               0.174757
# 2         id       212.5               0.076411               0.251169
# 3   pay_amt2       172.2               0.061920               0.313089
# 4        age       149.9               0.053901               0.366990
# 5   pay_amt3       149.7               0.053830               0.420820
# 6   pay_amt1       148.5               0.053398               0.474218
# 7   pay_amt6       141.7               0.050953               0.525171
# 8   pay_amt4       122.4               0.044013               0.569184
# 9  bill_amt3       119.5               0.042970               0.612154
